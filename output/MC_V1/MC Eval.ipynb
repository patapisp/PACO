# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load("a_mc.npy")
b = np.load("b_mc.npy")
e = np.load("est_mc.npy")

# %%
plt.imshow(np.median(b,axis = 0)/np.sqrt(np.median(a,axis = 0)))
plt.colorbar()
# Out:
# /home/evert/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median for 3295 results
#   r = func(a, **kwargs)
# /home/evert/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median for 3171 results
#   r = func(a, **kwargs)

# %%
plt.imshow(np.median(b,axis = 0)/np.median(a,axis = 0))
plt.colorbar()
# Out:
# /home/evert/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median for 3295 results
#   r = func(a, **kwargs)
# /home/evert/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:3405: RuntimeWarning: Invalid value encountered in median for 3171 results
#   r = func(a, **kwargs)

# %%
plt.imshow(np.mean(b,axis = 0))
plt.colorbar()

# %%
plt.imshow(np.var(b,axis =0))
plt.colorbar()

# %%
plt.imshow(np.mean(a,axis = 0))
plt.colorbar()

# %%
print(a.shape,b.shape)
# Out:
# (50, 100, 100) (50, 100, 100)

# %%
print(np.median(e[e > 0.0]),np.var(e[e > 0.0]))
# Out:
# 8.03059328958779 77.19853100483962
